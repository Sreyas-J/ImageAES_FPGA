# %%
AES_KEY_SIZE = 16

# AES S-box
s_box = (
    ,
)

r_con = (
    0x00, 0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40,
    0x80, 0x1B, 0x36, 0x6C, 0xD8, 0xAB, 0x4D, 0x9A,
    0x2F, 0x5E, 0xBC, 0x63, 0xC6, 0x97, 0x35, 0x6A,
    0xD4, 0xB3, 0x7D, 0xFA, 0xEF, 0xC5, 0x91, 0x39,
)

# %%
def sub_bytes(s):
    for i in range(4):
        for j in range(4):
            s[i][j] = s_box[s[i][j]]

def shift_rows(s):
    s[0][1], s[1][1], s[2][1], s[3][1] = s[1][1], s[2][1], s[3][1], s[0][1]
    s[0][2], s[1][2], s[2][2], s[3][2] = s[2][2], s[3][2], s[0][2], s[1][2]
    s[0][3], s[1][3], s[2][3], s[3][3] = s[3][3], s[0][3], s[1][3], s[2][3]

def add_round_key(s, k):
    for i in range(4):
        for j in range(4):
            s[i][j] ^= k[i][j]

xtime = lambda a: (((a << 1) ^ 0x1B) & 0xFF) if (a & 0x80) else (a << 1)

def mix_single_column(a):
    # see Sec 4.1.2 in The Design of Rijndael
    t = a[0] ^ a[1] ^ a[2] ^ a[3]
    u = a[0]
    a[0] ^= t ^ xtime(a[0] ^ a[1])
    a[1] ^= t ^ xtime(a[1] ^ a[2])
    a[2] ^= t ^ xtime(a[2] ^ a[3])
    a[3] ^= t ^ xtime(a[3] ^ u)


def mix_columns(s):
    for i in range(4):
        mix_single_column(s[i])

def bytes2matrix(text):
    """ Converts a 16-byte array into a 4x4 matrix.  """
    return [list(text[i:i+4]) for i in range(0, len(text), 4)]

def matrix2bytes(matrix):
    """ Converts a 4x4 matrix into a 16-byte array.  """
    return bytes(sum(matrix, []))

def xor_bytes(a, b):
    """ Returns a new byte array with the elements xor'ed. """
    return bytes(i^j for i, j in zip(a, b))

# %%
class AES:
    """
    Class for AES-128 encryption with CBC mode and PKCS#7.

    This is a raw implementation of AES, without key stretching or IV
    management. Unless you need that, please use `encrypt` and `decrypt`.
    """
    rounds_by_key_size = {16: 10, 24: 12, 32: 14}
    def __init__(self, master_key):
        """
        Initializes the object with a given key.
        """
        assert len(master_key) in AES.rounds_by_key_size
        self.n_rounds = AES.rounds_by_key_size[len(master_key)]
        self._key_matrices = self._expand_key(master_key)

    def _expand_key(self, master_key):
        """
        Expands and returns a list of key matrices for the given master_key.
        """
        # Initialize round keys with raw key material.
        key_columns = bytes2matrix(master_key)
        iteration_size = len(master_key) // 4

        i = 1
        while len(key_columns) < (self.n_rounds + 1) * 4:
            # Copy previous word.
            word = list(key_columns[-1])

            # Perform schedule_core once every "row".
            if len(key_columns) % iteration_size == 0:
                # Circular shift.
                word.append(word.pop(0))
                # Map to S-BOX.
                word = [s_box[b] for b in word]
                # XOR with first byte of R-CON, since the others bytes of R-CON are 0.
                word[0] ^= r_con[i]
                i += 1
            elif len(master_key) == 32 and len(key_columns) % iteration_size == 4:
                # Run word through S-box in the fourth iteration when using a
                # 256-bit key.
                word = [s_box[b] for b in word]

            # XOR with equivalent word from previous iteration.
            word = xor_bytes(word, key_columns[-iteration_size])
            key_columns.append(word)

        # Group key words in 4x4 byte matrices.
        return [key_columns[4*i : 4*(i+1)] for i in range(len(key_columns) // 4)]

    def encrypt_block(self, plaintext):
        """
        Encrypts a single block of 16 byte long plaintext.
        """
        assert len(plaintext) == 16

        plain_state = bytes2matrix(plaintext)

        add_round_key(plain_state, (bytes2matrix(bytes.fromhex('d6aa74fdd2af72fadaa678f1d6ab76fe'))))
        print("addrk round: 0",matrix2bytes(plain_state).hex())

        for i in range(1, self.n_rounds):
            sub_bytes(plain_state)
            print(f"sub_bytes round: {i}",matrix2bytes(plain_state).hex())
            shift_rows(plain_state)
            print(f"shift_rows round: {i}",matrix2bytes(plain_state).hex())
            mix_columns(plain_state)
            print(f"mix_columns round: {i}",matrix2bytes(plain_state).hex())
            add_round_key(plain_state, self._key_matrices[i])
            print(f"addrk round: {i}",matrix2bytes(plain_state).hex())

        sub_bytes(plain_state)
        print("sub_bytes ",matrix2bytes(plain_state).hex())
        shift_rows(plain_state)
        print("shift_rows ",matrix2bytes(plain_state).hex())
        add_round_key(plain_state, self._key_matrices[-1])
        print("addrk ",matrix2bytes(plain_state).hex())

        return matrix2bytes(plain_state)

# %%
key = bytes.fromhex('000102030405060708090a0b0c0d0e0f')
plaintext=bytes.fromhex('130F141D1A1F1E1D1A1C1C20242E2720')

aes = AES(key)
ciphertext = aes.encrypt_block(plaintext)

print("Final: ",ciphertext.hex())
# Out:
# addrk round: 0 c5a560e0c8b06ce7c0ba64d1f28551de
# sub_bytes round: 1 a606d0e1e8e75094baf4433e8997d11d
# shift_rows round: 1 a6e7431de8f4d1e1ba97d0948906503e
# mix_columns round: 1 3babe06ffc929ddf897031a16d4b6daa
# addrk round: 1 ed0194922e3def2553d64950bbe01b54
# sub_bytes round: 2 557c224f3127df3fedf63b53eae1af20
# shift_rows round: 2 55273b2031f6af4fede1223fea7cdf53
# mix_columns round: 2 d87664a383635394e46d0991c73bc620
# addrk round: 2 6ee4aba8e75eee655af6cc91af0b75de
# sub_bytes round: 3 9f6962c29458284dbe424b81792b9d1d
# shift_rows round: 3 9f584b1d94429dc2be2b624d79692881
# mix_columns round: 3 9bef7693aa6eaae73503860ae052d8d3
# addrk round: 3 2d1002dd78ac6358595a8ab5e43b6792
# sub_bytes round: 4 d8ca77c1bc91fb6acbbe7ed569e2854f
# shift_rows round: 4 d8917e4fbcbe85c1cbe2776a69cafbd5
# mix_columns round: 4 322c6402fe8e4b7dade77907b9252a3b
# addrk round: 4 75db93be6bbb757e548b4bbb4420a7c6
# sub_bytes round: 5 9db9dcae7fea9df3203db3ea1bb75cb4
# shift_rows round: 5 9deab3b47f3d5cae20b7dcf31bb99dea
# mix_columns round: 5 0328cd964b4f13a7add93af69124a6c6
# addrk round: 5 3f826e7ee2d08e4cfd2a95a13cd2846c
# sub_bytes round: 6 75139ff39870192954e52a32ebb55f50
# shift_rows round: 6 75702a5098e55ff354b59f29eb131932
# mix_columns round: 6 00bba165b35bcdf4dab6bf84d3d49c48
# addrk round: 6 5e82ae1844fd5f627de38245d9778323
# sub_bytes round: 7 5813e4ad1b54cfaaff11136e35f5ec26
# shift_rows round: 7 585413261b11ecadfff5e4aa3513cf6e
# mix_columns round: 7 79e340e344bb2591af933c44fe37115f
# addrk round: 7 6d1a30f9a7e4c71deb99e309b09ed179
# sub_bytes round: 8 3ca204995c69c6a4e9ee1101e70b3eb6
# shift_rows round: 8 3c6911b65cee3e99e90b04a4e7a2c601
# mix_columns round: 8 646bb64b36407e1d74571d7cefe8d154
# addrk round: 8 2328317e925c1ba49441a7884157ab86
# sub_bytes round: 9 2634c7f34f4aaf4922835cc4835b6244
# shift_rows round: 9 264a5c444f8362f3225bc7498334afc4
# mix_columns round: 9 8a1218f4910706cd278f37682ac5a596
# addrk round: 9 de8b2a25618251a5371cdaf494e932d8
# sub_bytes  1d3de53fef13d1069a9c57bf221e2361
# shift_rows  1d135761ef9c233f9a1ee506223dd1bf
# addrk  0e024a1e0c0869286919428d6f16e17a
# Final:  0e024a1e0c0869286919428d6f16e17a
